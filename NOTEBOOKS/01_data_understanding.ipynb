# %% [markdown]
# # Supply Chain Control Tower – Data Understanding & Profiling
#
# ## Project Objective
#
# The goal of this project is to build an end-to-end Supply Chain Control Tower and Executive Analytics Platform using the DataCo Smart Supply Chain dataset.
#
# The project aims to identify:
# - shipment delays
# - logistics bottlenecks
# - profitability issues
# - regional performance gaps
# - operational risks
#
# The cleaned and transformed dataset will later be used for:
# - SQL warehouse modeling
# - executive KPI reporting
# - Power BI dashboards
# - operational analytics
# - supply chain performance monitoring
#
# ---
#
# ## Key Focus Areas
#
# - Order performance analysis
# - Logistics and shipment monitoring
# - Revenue and profitability analysis
# - Customer and regional insights
# - Operational risk detection
# - Executive dashboard reporting

# %% [markdown]
# # Library Imports
#
# The following libraries are imported for data loading, profiling, visualization and preprocessing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %% [markdown]
# # Dataset Loading
#
# The raw DataCo Smart Supply Chain dataset is loaded into a Pandas DataFrame for initial exploration and profiling.

# %%
df=pd.read_csv("../Data/Raw/DataCoSupplyChainDataset.csv",encoding='latin-1')

# %% [markdown]
# # Initial Dataset Preview
#
# Displaying the first few rows to understand the overall structure and available attributes within the dataset.

# %%
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %% [markdown]
# # Column Exploration
#
# Reviewing all available columns to understand the business entities and overall dataset structure.

# %%
df.columns.tolist()
# Out:
# ['Type',
#  'Days for shipping (real)',
#  'Days for shipment (scheduled)',
#  'Benefit per order',
#  'Sales per customer',
#  'Delivery Status',
#  'Late_delivery_risk',
#  'Category Id',
#  'Category Name',
#  'Customer City',
#  'Customer Country',
#  'Customer Email',
#  'Customer Fname',
#  'Customer Id',
#  'Customer Lname',
#  'Customer Password',
#  'Customer Segment',
#  'Customer State',
#  'Customer Street',
#  'Customer Zipcode',
#  'Department Id',
#  'Department Name',
#  'Latitude',
#  'Longitude',
#  'Market',
#  'Order City',
#  'Order Country',
#  'Order Customer Id',
#  'order date (DateOrders)',
#  'Order Id',
#  'Order Item Cardprod Id',
#  'Order Item Discount',
#  'Order Item Discount Rate',
#  'Order Item Id',
#  'Order Item Product Price',
#  'Order Item Profit Ratio',
#  'Order Item Quantity',
#  'Sales',
#  'Order Item Total',
#  'Order Profit Per Order',
#  'Order Region',
#  'Order State',
#  'Order Status',
#  'Order Zipcode',
#  'Product Card Id',
# ...

# %% [markdown]
# # Dataset Structure & Datatypes
#
# Inspecting:
# - total rows and columns
# - datatypes
# - non-null counts
# - overall dataset structure

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  str
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  str
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  str
#  9   Customer City                  180519 non-null  str
#  10  Customer Country               180519 non-null  str
#  11  Customer Email                 180519 non-null  str
# ...

# %% [markdown]
# # Missing Value Analysis
#
# Analyzing missing values to identify:
# - incomplete fields
# - structurally empty columns
# - potential data quality issues

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Product Description              180519
# Order Zipcode                    155679
# Customer Lname                        8
# Customer Zipcode                      3
# Type                                  0
# Order Profit Per Order                0
# Order Item Cardprod Id                0
# Order Item Discount                   0
# Order Item Discount Rate              0
# Order Item Id                         0
# Order Item Product Price              0
# Order Item Profit Ratio               0
# Order Item Quantity                   0
# Sales                                 0
# Order Item Total                      0
# Order Region                          0
# order date (DateOrders)               0
# Order State                           0
# Order Status                          0
# Product Card Id                       0
# Product Category Id                   0
# Product Image                         0
# Product Name                          0
# ...

# %% [markdown]
# # Investigation of High Missing Value Columns
#
# Further investigating columns with the highest percentage of missing values to determine whether they should be retained, transformed or removed.

# %%
df[["Product Description", "Order Zipcode"]].head(20)
# Out:
#     Product Description  Order Zipcode
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
# 5                   NaN            NaN
# 6                   NaN            NaN
# 7                   NaN            NaN
# 8                   NaN            NaN
# 9                   NaN            NaN
# 10                  NaN            NaN
# 11                  NaN            NaN
# 12                  NaN            NaN
# 13                  NaN            NaN
# 14                  NaN            NaN
# 15                  NaN            NaN
# 16                  NaN            NaN
# 17                  NaN            NaN
# 18                  NaN            NaN
# 19                  NaN            NaN

# %% [markdown]
# # Missing Value Percentage Validation
#
# Calculating the percentage of missing values for the identified high-null columns.

# %%
(
    df[["Product Description", "Order Zipcode"]]
    .isnull()
    .mean() * 100
).round(2)
# Out:
# Product Description    100.00
# Order Zipcode           86.24
# dtype: float64

# %% [markdown]
# # Business-Oriented Column Review
#
# Reviewing the complete column list again to begin business-domain classification and analytical relevance assessment.

# %%
df.columns.tolist()
# Out:
# ['Type',
#  'Days for shipping (real)',
#  'Days for shipment (scheduled)',
#  'Benefit per order',
#  'Sales per customer',
#  'Delivery Status',
#  'Late_delivery_risk',
#  'Category Id',
#  'Category Name',
#  'Customer City',
#  'Customer Country',
#  'Customer Email',
#  'Customer Fname',
#  'Customer Id',
#  'Customer Lname',
#  'Customer Password',
#  'Customer Segment',
#  'Customer State',
#  'Customer Street',
#  'Customer Zipcode',
#  'Department Id',
#  'Department Name',
#  'Latitude',
#  'Longitude',
#  'Market',
#  'Order City',
#  'Order Country',
#  'Order Customer Id',
#  'order date (DateOrders)',
#  'Order Id',
#  'Order Item Cardprod Id',
#  'Order Item Discount',
#  'Order Item Discount Rate',
#  'Order Item Id',
#  'Order Item Product Price',
#  'Order Item Profit Ratio',
#  'Order Item Quantity',
#  'Sales',
#  'Order Item Total',
#  'Order Profit Per Order',
#  'Order Region',
#  'Order State',
#  'Order Status',
#  'Order Zipcode',
#  'Product Card Id',
# ...

# %% [markdown]
# # Business Entity Mapping
#
# ## Order Domain
#
# These columns represent transactional order lifecycle information and order-level commercial activity.
#
# - Order Id
# - Order Item Id
# - Order Status
# - Type
# - DateOrders
# - Order Item Quantity
# - Order Item Discount
# - Order Item Discount Rate
# - Order Item Product Price
# - Order Item Total
# - Sales
#
# ---
#
# ## Customer Domain
#
# These columns describe customer identity, segmentation and customer-related geography attributes.
#
# - Customer Id
# - Customer Fname
# - Customer Lname
# - Customer Full Name
# - Customer Email
# - Customer Password
# - Customer Segment
# - Customer Street
# - Customer City
# - Customer State
# - Customer Country
# - Customer Zipcode
#
# ---
#
# ## Product Domain
#
# These columns define product hierarchy, product catalog information and merchandising structure.
#
# - Product Card Id
# - Product Category Id
# - Category Id
# - Category Name
# - Product Name
# - Department Id
# - Department Name
# - Product Description
# - Product Image
# - Product Price
#
# ---
#
# ## Logistics Domain
#
# These columns represent shipment execution, delivery performance and logistics operations.
#
# - Shipping Mode
# - Days for shipment (scheduled)
# - Days for shipping (real)
# - Delivery Status
# - Late_delivery_risk
#
# ---
#
# ## Geography Domain
#
# These columns support regional analysis, market segmentation and geographic performance monitoring.
#
# - Order City
# - Order State
# - Order Country
# - Order Region
# - Latitude
# - Longitude
# - Market
# - Customer City
# - Customer State
#
# ---
#
# ## Finance Domain
#
# These columns define revenue, profitability and pricing-related business metrics.
#
# - Benefit per order
# - Sales
# - Order Item Total
# - Order Profit Per Order
# - Order Item Discount
# - Order Item Discount Rate
# - Product Price
#
# ---
#
# ## Risk / Operations Domain
#
# These columns are important for operational monitoring, delay analysis and supply chain risk detection.
#
# - Late_delivery_risk
# - Order Status
# - Delivery Status
# - Days for shipping (real)
# - Days for shipment (scheduled)

# %% [markdown]
# # Drop Candidate Columns
#
# The following columns have been identified as potential drop candidates based on missing values, redundancy, low analytical usefulness or limited business relevance for executive supply chain analytics.
#
# - Product Description
# - Product Image
# - Customer Password
# - Order Zipcode
# - Customer Email
# - Customer Fname
# - Customer Lname
# - Customer Street
#
# ---
#
# ## Reasons for Potential Removal
#
# ### High Missing Values
# - Product Description
# - Order Zipcode
#
# ### Redundant Customer Identity Information
# - Customer Fname
# - Customer Lname
# ### Low or No Analytical Business Value
# - Product Image
# - Customer Password
# - Customer Email
# - Customer Street
#
# These columns may be formally removed during the data cleaning and ETL phase after final validation.

# %% [markdown]
# # Column Audit & Data Profiling
#
# Creating a structured audit table to evaluate:
# - datatypes
# - missing values
# - uniqueness
# - analytical usefulness
# - data quality characteristics
#
# This audit will guide future cleaning and ETL decisions.

# %%
column_audit = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.values,
    "Missing Values": df.isnull().sum().values,
    "Missing %": (
        df.isnull().mean() * 100
    ).round(2).values,
    "Unique Values": df.nunique().values
})

column_audit
# Out:
#                            Column Data Type  Missing Values  Missing %  \
# 0                            Type       str               0       0.00
# 1        Days for shipping (real)     int64               0       0.00
# 2   Days for shipment (scheduled)     int64               0       0.00
# 3               Benefit per order   float64               0       0.00
# 4              Sales per customer   float64               0       0.00
# 5                 Delivery Status       str               0       0.00
# 6              Late_delivery_risk     int64               0       0.00
# 7                     Category Id     int64               0       0.00
# 8                   Category Name       str               0       0.00
# 9                   Customer City       str               0       0.00
# 10               Customer Country       str               0       0.00
# 11                 Customer Email       str               0       0.00
# ...

# %% [markdown]
# # Data Profiling Observations
#
# ## Updated Drop List
#
# - Product Description
# - Product Image
# - Customer Password
# - Order Zipcode
# - Customer Email
# - Customer Fname
# - Customer Lname
# - Customer Street
# - Product Status
#
# ---
#
# ## Important Categorical Dimensions
#
# These columns have low-to-medium cardinality and are valuable for filtering, segmentation and dashboard slicing.
#
# - Shipping Mode
# - Delivery Status
# - Customer Segment
# - Market
# - Order Status
# - Category Name
# - Department Name
# - Order Region
#
# These can later become:
# - Power BI slicers
# - segmentation filters
# - KPI breakdown dimensions
#
# ---
#
# ## Important Metrics / KPIs
#
# ### Financial Metrics
#
# - Sales
# - Benefit per order
# - Order Profit Per Order
# - Order Item Total
# - Order Item Discount
# - Order Item Discount Rate
# - Product Price
#
# ### Logistics Metrics
#
# - Days for shipping (real)
# - Days for shipment (scheduled)
# - Late_delivery_risk
#
# These will later help build:
# - profitability KPIs
# - delay analysis
# - OTIF metrics
# - operational performance dashboards
#
# ---
#
# ## Redundancy Observations
#
# Potential overlapping columns identified:
#
# - Product Card Id and Order Item Cardprod Id
# - Category Id and Product Category Id
#
# These columns require further validation during cleaning to determine whether they are duplicates or represent different hierarchy levels.
#
# ---
#
# ## Datatype Conversion Required
#
# The following columns are currently stored as strings and require datetime conversion:
#
# - order date (DateOrders)
# - shipping date (DateOrders)
#
# These will later support:
# - time-series analysis
# - monthly KPIs
# - trend analysis
# - shipment delay calculations
#
# ---
#
# ## Important Business Insights
#
# - The dataset is at order-item granularity.
# - The dataset is highly suitable for logistics and supply chain analytics.
# - Geography coverage is strong with country, region, state and coordinate-level data.
# - Shipment and delay-related fields provide strong opportunities for operational risk analysis.
# - Financial and shipment metrics together make the dataset suitable for executive KPI dashboards and control tower reporting.

# %% [markdown]
# # Summary & Next Steps
#
# ## Key Findings
#
# - The dataset operates at order-item level granularity.
# - Shipment and logistics data are highly suitable for supply chain analytics.
# - Several low-value and high-null columns were identified as drop candidates.
# - Geography coverage is strong and supports regional analytics.
# - Financial and operational metrics provide strong KPI opportunities.
#
# ---
#
# ## Next Steps
#
# The next notebook will focus on:
# - data cleaning
# - datatype conversion
# - null handling
# - duplicate validation
# - column standardization
# - ETL preparation
#
# Notebook:
# `02_cleaning.ipynb`
